# %% [markdown]
# # Even reduction

# %%
using DynamicPolynomials
@polyvar x
# Out:
# (x,)

# %% [markdown]
# We would like to find the minimum value of the following polynomial:

# %%
poly = x^4 - 2x^2

using SumOfSquares

# %% [markdown]
# We define the custom action as follows:

# %%
struct OnSign <: Symmetry.OnMonomials end
using PermutationGroups
import SymbolicWedderburn
SymbolicWedderburn.coeff_type(::OnSign) = Float64
function SymbolicWedderburn.action(::OnSign, p::Permutation, mono::AbstractMonomial)
    if isone(p) || iseven(DynamicPolynomials.degree(mono))
        return 1 * mono
    else
        @assert p.perm == perm"(1,2)"
        return -1 * mono
    end
end
G = PermGroup([perm"(1,2)"])
# Out:
# Permutation group on 1 generator generated by
#  (1,2)

# %% [markdown]
# We can exploit the symmetry as follows:

# %%
import Clarabel
solver = Clarabel.Optimizer
model = Model(solver)
@variable(model, t)
@objective(model, Max, t)
pattern = Symmetry.Pattern(G, OnSign())
con_ref = @constraint(model, poly - t in SOSCone(), symmetry = pattern)
optimize!(model)
value(t)
# Out:
# -------------------------------------------------------------
#            Clarabel.jl v0.10.0  -  Clever Acronym
#                    (c) Paul Goulart
#                 University of Oxford, 2022
# -------------------------------------------------------------
#
# problem:
#   variables     = 5
#   constraints   = 9
#   nnz(P)        = 0
#   nnz(A)        = 11
#   cones (total) = 3
#     : Zero        = 1,  numel = 5
#     : Nonnegative = 1,  numel = 1
#     : SecondOrder = 1,  numel = 3
#
# settings:
#   linear algebra: direct / qdldl, precision: Float64
#   max iter = 200, time limit = Inf,  max step = 0.990
#   tol_feas = 1.0e-08, tol_gap_abs = 1.0e-08, tol_gap_rel = 1.0e-08,
#   static reg : on, ϵ1 = 1.0e-08, ϵ2 = 4.9e-32
#   dynamic reg: on, ϵ = 1.0e-13, δ = 2.0e-07
#   iter refine: on, reltol = 1.0e-13, abstol = 1.0e-12,
#                max iter = 10, stop ratio = 5.0
#   equilibrate: on, min_scale = 1.0e-04, max_scale = 1.0e+04
#                max iter = 10
#
# iter    pcost        dcost       gap       pres      dres      k/t        μ       step
# ---------------------------------------------------------------------------------------------
#   0   1.9811e-16   8.8727e-17  1.09e-16  3.75e-01  2.98e-01  1.00e+00  1.87e+00   ------
#   1   7.1205e-01   7.3637e-01  2.43e-02  5.21e-02  3.67e-02  1.57e-01  2.42e-01  8.81e-01
#   2   9.5850e-01   9.9167e-01  3.32e-02  1.29e-02  7.29e-03  6.72e-02  4.70e-02  8.53e-01
#   3   9.8665e-01   9.9077e-01  4.11e-03  2.43e-03  1.48e-03  1.05e-02  9.77e-03  8.29e-01
#   4   1.0001e+00   9.9992e-01  1.42e-04  9.15e-05  5.81e-05  9.92e-05  3.90e-04  9.62e-01
#   5   1.0000e+00   1.0000e+00  1.90e-06  1.25e-06  7.97e-07  1.41e-06  5.35e-06  9.86e-01
#   6   1.0000e+00   1.0000e+00  4.39e-08  2.93e-08  1.86e-08  3.34e-08  1.25e-07  9.77e-01
#   7   1.0000e+00   1.0000e+00  1.08e-09  7.36e-10  4.67e-10  8.64e-10  3.14e-09  9.75e-01
# ---------------------------------------------------------------------------------------------
# Terminated with status = solved
# solve time =  777μs
# -0.9999999977220708

# %% [markdown]
# We indeed find `-1`, let's verify that symmetry was exploited:

# %%
gram_matrix(con_ref)
# Out:
# BlockDiagonalGramMatrix with 2 blocks:
# [1] Block with row/column basis:
#      Simple basis:
#   FixedBasis([1.0·1 + 0.0·x + 0.0·x², 0.0·1 + 0.0·x + 1.0·x²])
#     And entries in a 2×2 SymMatrix{Float64}:
#       0.9999999977220708  -1.000000000898501
#      -1.000000000898501    1.0
# [2] Block with row/column basis:
#      Simple basis:
#   FixedBasis([0.0·1 + 1.0·x + 0.0·x²])
#     And entries in a 1×1 SymMatrix{Float64}:
#      1.7970022023157515e-9

# %% [markdown]
# ---
#
# *This notebook was generated using [Literate.jl](https://github.com/fredrikekre/Literate.jl).*
